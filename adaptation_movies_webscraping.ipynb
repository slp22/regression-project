# %% [markdown]
# # Exporting American Movie Box Office Hits
#
# ### boxofficemojo.com data acquisition

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
import dateutil.parser
import time
import random

# %% [markdown]
# # `movies_urls` list
# Use the link structure of offset to add 100 to get the next page.

# %%
offset = 0
base_url = 'https://www.boxofficemojo.com/genre/sg1625223425/?offset='

movies_urls = []

for url in range(10):
    movies_urls.append(base_url + str(offset))
    offset = offset + 100

# %% [markdown]
# # `movies_dict`
# Get link stub from index page.

# %%
def scrape_movies(url, movies_data):
    response = requests.get(url)
    status = response.status_code
    if status == 200:
        print('Status is 200') # double check code runs for nine pages
        page = response.text
        soup = bs(page, "lxml")
        table = soup.find("table")
        rows = [row for row in table.find_all('tr')] 
        for row in rows:
            movies_data.append(row)
    else:
        print(f"Oops! Received status code {status}")
        return None
    
movies_data = []

for movie_url in movies_urls:
    scrape_movies(movie_url, movies_data)
    
# movies_data
# Out:
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200

# %%
# pop first element of each soup which has the header names in the row
movies_data.pop(0)

movies_dict = {}

for row in movies_data:
    items = row.find_all('td')
    try:
        link = items[1].find('a')
        title, url = link.text, link['href']
        movies_dict[title] = [url] + [i.text for i in items]
    except IndexError:
        continue
        

# print(movies_dict)

# %% [markdown]
# # `adaptation_movies_df`

# %%
# df using movies dict from above, including link_stub

adaptation_movies_df = pd.DataFrame(movies_dict).T  #transpose
adaptation_movies_df.columns = ['link_stub', 'rank', 'movie_title', 
                    'lifetime_gross', 'max_theaters', 'opening_weekend', 
                    'opening_theathers', 'release_date', 'distributor']
adaptation_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 945 entries, The Avengers to Amityville: The Awakening
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   link_stub          945 non-null    object
#  1   rank               945 non-null    object
#  2   movie_title        945 non-null    object
#  3   lifetime_gross     945 non-null    object
#  4   max_theaters       945 non-null    object
#  5   opening_weekend    945 non-null    object
#  6   opening_theathers  945 non-null    object
#  7   release_date       945 non-null    object
#  8   distributor        945 non-null    object
# dtypes: object(9)
# memory usage: 73.8+ KB

# %%
adaptation_movies_df.head()
# Out:
#                                             link_stub rank     movie_title  \
# 101 Dalmatians  /title/tt0115433/?ref_=bo_ge_table_49  149  101 Dalmatians
# 102 Dalmatians  /title/tt0211181/?ref_=bo_ge_table_35  335  102 Dalmatians
# 12 Monkeys      /title/tt0114746/?ref_=bo_ge_table_85  385      12 Monkeys
# 13 Sins         /title/tt2059171/?ref_=bo_ge_table_56  956         13 Sins
# 1984             /title/tt0087803/?ref_=bo_ge_table_8  808            1984
#
#                lifetime_gross max_theaters opening_weekend opening_theathers  \
# 101 Dalmatians   $136,189,294        2,901     $33,504,025             2,794
# 102 Dalmatians    $66,957,026        2,704     $19,883,351             2,704
# 12 Monkeys        $57,141,459        1,629        $184,776                 3
# 13 Sins               $13,809           45          $9,261                45
# 1984               $8,430,492          295         $29,897                 1
#
#                release_date_x                            distributor_x  \
# 101 Dalmatians   Nov 27, 1996  Walt Disney Studios Motion Pictures\n\n
# 102 Dalmatians   Nov 22, 2000  Walt Disney Studios Motion Pictures\n\n
# 12 Monkeys       Dec 29, 1995                   Universal Pictures\n\n
# 13 Sins          Apr 18, 2014                           RADiUS-TWC\n\n
# 1984             Dec 14, 1984           The Samuel Goldwyn Company\n\n
#
#                 domestic_total_gross  international_total_gross  \
# 101 Dalmatians             136189294                  184500000
# 102 Dalmatians              66957026                  116654745
# 12 Monkeys                  57141459                  111698000
# 13 Sins                        13809                     813104
# 1984                         8430492                    8430492
#
#                 worldwide_total_gross  domestic_opening    budget  \
# 101 Dalmatians              320689294          33504025         0
# 102 Dalmatians              183611771          19883351  85000000
# 12 Monkeys                  168839459            184776         0
# 13 Sins                        826913              9261         0
# 1984                                0             29897         0
#
#                release_date_y  runtime                        distributor_y  \
# 101 Dalmatians     1996-11-27    103.0  Walt Disney Studios Motion Pictures
# 102 Dalmatians     2000-11-22    100.0  Walt Disney Studios Motion Pictures
# 12 Monkeys         1995-12-29    129.0                   Universal Pictures
# 13 Sins            2014-04-11     93.0                           RADiUS-TWC
# 1984               1984-12-14    113.0           The Samuel Goldwyn Company
#
#                                           genres rating
# 101 Dalmatians  Adventure, Comedy, Crime, Family   None
# 102 Dalmatians         Adventure, Comedy, Family   None
# 12 Monkeys             Mystery, Sci-Fi, Thriller      R
# 13 Sins                         Horror, Thriller      R
# 1984                               Drama, Sci-Fi   None

# %% [markdown]
# # helper functions
# # `money_to_int()`  `runtime_to_minutes()`  `to_date()`

# %%
# helper functions parse strings into appropriate data types

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# # `get_movie_value()`

# %%
# function to scrape values from each movie page, will pass field_name in next function

def get_movie_value(soup, field_name):
 
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %% [markdown]
# # `get_movie_dict()`

# %%
# create movie dict to collect values from get_movie_value function from above

def get_movie_dict(link):
    
    base_url = 'https://www.boxofficemojo.com'
    
    # create full url to scrape
    url = base_url + link
    
    # request HTML and parse
    response = requests.get(url)
    status = response.status_code
    if status == 200:
        page = response.text
        soup = bs(page, "lxml")
    else:
        print(f"Oops! Received status code {status}")
        
    headers = ['movie_title', 
               'domestic_total_gross',
               'international_total_gross',
               'worldwide_total_gross',
               'domestic_opening',
               'budget',
               'release_date',
               'runtime',
               'distributor',
               'genres',
               'rating'
              ]

    #get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()
    print(title) # print movie title to make sure code is running

    '''
    Get GROSS VALUES from performance summary table on left side of each movie page
    '''
    # domestic $$$
    try:     
        raw_domestic_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                        .find_all('span', class_='money')[0].text)
        # convert raw to int       
        domestic_total_gross = money_to_int(raw_domestic_total_gross)
    except:
        domestic_total_gross= 0
    
    # international $$$
    try: 
        raw_international_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                        .find_all('span', class_='money')[1].text)
        #convert raw to int    
        international_total_gross = money_to_int(raw_international_total_gross)
    except:
         international_total_gross = 0

    # worldwide $$$
    try: 
        raw_worldwide_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                        .find_all('span', class_='money')[2]
                                        .text)
        # convert raw to int
        worldwide_total_gross = money_to_int(raw_worldwide_total_gross)

    except:
        worldwide_total_gross = 0

    '''
    Get MOVIE DETAILS from summary details table in center of each movie page
    '''    
    # domestic opening $$$ 
    try: 
        raw_domestic_opening = get_movie_value(soup,'Domestic Opening')
        
        # convert to int
        domestic_opening = money_to_int(raw_domestic_opening)
    except:
        domestic_opening = 0
    
    # budget $$$
    try: 
        raw_budget = get_movie_value(soup,'Budget')
        
        # convert budget to int
        budget = money_to_int(raw_budget)
    except:
        budget = 0
    
    # release date
    try: 
        raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
        # convert date to dt
        release_date = to_date(raw_release_date)
    except:
        release_date = 0

    # runtime 
    try: 
        raw_runtime = get_movie_value(soup,'Running')
        # convert runtime to minutes
        runtime = runtime_to_minutes(raw_runtime)
    except:
        runtime = 0 
    
    # distributor
    try:  
        raw_distributor = get_movie_value(soup,'Distributor')
        # clean up 
        distributor = raw_distributor.replace('See full company information', '').replace('\n\n', '')
    except:
        distributor = 'NA' 

    # genres
    try: 
        genres = get_movie_value(soup,'Genres').replace('\n    \n        ', ', ')
    except:
        genres = 'NA'

    # rating    
    try: 
        rating = get_movie_value(soup,'MPAA')
    except:
        rating = 'NA'
    
    # movie dictionary
    movie_dict = dict(zip(headers, [title,
                                    domestic_total_gross,
                                    international_total_gross,
                                    worldwide_total_gross,
                                    domestic_opening,
                                    budget,
                                    release_date,
                                    runtime,
                                    distributor,
                                    genres,
                                    rating]))
    
#     print(movie_dict)

    return movie_dict

# %% [markdown]
# # `adaptation_movie_page_info_list`

# %%
# loop to pass link using get_movie_dict() function from above

adaptation_movie_page_info_list = []

for link in adaptation_movies_df.link_stub:
    adaptation_movie_page_info_list.append(get_movie_dict(link))
# Out:
# The Avengers
# The Lion King
# The Dark Knight
# Beauty and the Beast
# Avengers: Age of Ultron
# The Dark Knight Rises
# Captain Marvel
# The Hunger Games: Catching Fire
# Wonder Woman
# Iron Man 3
# Captain America: Civil War
# The Hunger Games
# Spider
# Transformers: Revenge of the Fallen
# Spider
# Guardians of the Galaxy Vol. 2
# Harry Potter and the Deathly Hallows: Part 2
# Spider
# The Jungle Book
# Deadpool
# Jurassic Park
# Transformers: Dark of the Moon
# The Hunger Games: Mockingjay
# Spider
# Joker
# Aquaman
# Spider
# Alice in Wonderland
# Guardians of the Galaxy
# Batman v Superman: Dawn of Justice
# Suicide Squad
# Transformers
# Iron Man
# Deadpool 2
# Harry Potter and the Sorcerer's Stone
# Thor: Ragnarok
# Iron Man 2
# Harry Potter and the Half
# The Twilight Saga: Eclipse
# The Twilight Saga: New Moon
# Harry Potter and the Deathly Hallows: Part 1
# The Twilight Saga: Breaking Dawn
# Harry Potter and the Order of the Phoenix
# The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Man of Steel
# Harry Potter and the Goblet of Fire
# The Hunger Games: Mockingjay
# The Twilight Saga: Breaking Dawn
# The Grinch
# Shrek
# The Amazing Spider
# Harry Potter and the Chamber of Secrets
# How the Grinch Stole Christmas
# Captain America: The Winter Soldier
# Star Trek
# I Am Legend
# Batman
# Night at the Museum
# Men in Black
# Harry Potter and the Prisoner of Azkaban
# Transformers: Age of Extinction
# X
# War of the Worlds
# X
# Doctor Strange
# The Lost World: Jurassic Park
# Justice League
# Star Trek Into Darkness
# The Martian
# Logan
# Shang
# Big Hero 6
# Mission: Impossible
# Alvin and the Chipmunks: The Squeakquel
# King Kong
# How to Train Your Dragon
# The Da Vinci Code
# Alvin and the Chipmunks
# Ant
# Mission: Impossible II
# X2: X
# The Lorax
# Venom
# 300
# Mission: Impossible
# Charlie and the Chocolate Factory
# Thor: The Dark World
# Batman Begins
# The Amazing Spider
# The Mummy Returns
# Godzilla
# Superman Returns
# Mission: Impossible
# Twilight
# 22 Jump Street
# The Batman
# Teenage Mutant Ninja Turtles
# Men in Black II
# Spider
# Batman Forever
# The Fugitive
# Black Widow
# The Simpsons Movie
# Thor
# Mission: Impossible
# Ant
# Planet of the Apes
# X
# Men in Black 3
# How to Train Your Dragon 2
# Captain America: The First Avenger
# The Karate Kid
# Three Men and a Baby
# Eternals
# Clash of the Titans
# The SpongeBob Movie: Sponge Out of Water
# Batman Returns
# The Polar Express
# Star Trek Beyond
# The Firm
# The Longest Yard
# X
# X
# The Mummy
# Fantastic Four
# Horton Hears a Who!
# Scooby
# Sex and the City
# Divergent
# Sonic the Hedgehog
# X
# True Lies
# I, Robot
# Doctor Dolittle
# Pokémon Detective Pikachu
# The Smurfs
# The Chronicles of Narnia: Prince Caspian
# A Few Good Men
# Shazam!
# Stuart Little
# Cheaper by the Dozen
# 21 Jump Street
# Ready Player One
# 101 Dalmatians
# The Incredible Hulk
# Wanted
# Superman
# Mission: Impossible III
# Alvin and the Chipmunks: Chipwrecked
# The Wolverine
# The Departed
# Hulk
# Fantastic 4: Rise of the Silver Surfer
# The Last Airbender
# Lara Croft: Tomb Raider
# The Flintstones
# Get Smart
# The Divergent Series: Insurgent
# The Peanuts Movie
# Transformers: The Last Knight
# The Ring
# The Nutty Professor
# Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan
# Ghostbusters
# Kingsman: The Secret Service
# Bumblebee
# Mr. Deeds
# Ocean's Twelve
# Charlie's Angels
# The Fault in Our Stars
# Cloudy with a Chance of Meatballs
# The Birdcage
# Nutty Professor II: The Klumps
# The Mask
# Cloudy with a Chance of Meatballs 2
# A Series of Unfortunate Events
# Ocean's Thirteen
# S.W.A.T.
# Green Lantern
# You've Got Mail
# Ghost Rider
# Peter Rabbit
# Dumbo
# Wild Wild West
# The Addams Family
# Dr. Dolittle 2
# Mr. Peabody & Sherman
# The Grudge
# Fun with Dick and Jane
# Freaky Friday
# Star Trek IV: The Voyage Home
# The Upside
# The Princess Diaries
# Superman II
# Dune
# Little Women
# Epic
# Watchmen
# The Angry Birds Movie
# Batman & Robin
# 300: Rise of an Empire
# Uncharted
# The Italian Job
# George of the Jungle
# Road to Perdition
# The Chronicles of Narnia: The Voyage of the Dawn Treader
# Dick Tracy
# Rise of the Guardians
# Just Go with It
# Daredevil
# The Girl with the Dragon Tattoo
# The Mummy: Tomb of the Dragon Emperor
# The Maze Runner
# Gone in 60 Seconds
# Maverick
# The Equalizer
# The Cat in the Hat
# Rampage
# Contact
# Charlie's Angels: Full Throttle
# Vanilla Sky
# Arrival
# The Rugrats Movie
# Jumanji
# Casper
# Yogi Bear
# Cowboys & Aliens
# Kingsman: The Golden Circle
# The Green Hornet
# Inspector Gadget
# Downton Abbey
# Sex and the City 2
# The Princess Diaries 2: Royal Engagement
# The Magnificent Seven
# Flubber
# Star Trek: First Contact
# The Haunting
# Prince of Persia: The Sands of Time
# RED
# Father of the Bride
# Oblivion
# Percy Jackson & the Olympians: The Lightning Thief
# The Muppets
# Starsky & Hutch
# Miss Peregrine's Home for Peculiar Children
# The Naked Gun 2½: The Smell of Fear
# Annie
# Alvin and the Chipmunks: The Road Chip
# Alita: Battle Angel
# Pokémon: The First Movie
# The SpongeBob SquarePants Movie
# Power Rangers
# Scooby
# The X Files
# Wrath of the Titans
# Disclosure
# Charlotte's Web
# Cheaper by the Dozen 2
# Fried Green Tomatoes
# Blade II
# Bridge to Terabithia
# Star Trek: The Motion Picture
# The Pink Panther
# Teenage Mutant Ninja Turtles: Out of the Shadows
# Maze Runner: The Scorch Trials
# Eight Below
# Payback
# Congo
# The Notebook
# The Texas Chainsaw Massacre
# The Dukes of Hazzard
# Jumper
# Goosebumps
# War Horse
# Dark Shadows
# Hannah Montana: The Movie
# The Day the Earth Stood Still
# Cape Fear
# Star Trek II: The Wrath of Khan
# The Naked Gun: From the Files of Police Squad!
# Teenage Mutant Ninja Turtles II: The Secret of the Ooze
# Man on Fire
# The Adventures of Tintin
# Where the Wild Things Are
# The A
# Father of the Bride Part II
# Rugrats in Paris
# Star Trek III: The Search for Spock
# Paddington
# The Untouchables
# Pete's Dragon
# The Ring Two
# Cocoon
# Hellboy II: The Golden Army
# Constantine
# Star Trek: Generations
# 2 Guns
# The Horse Whisperer
# Garfield
# Coraline
# Eragon
# Star Trek VI: The Undiscovered Country
# Sin City
# Hugo
# John Carter
# Hotel for Dogs
# Dinner for Schmucks
# Hercules
# Three Men and a Little Lady
# Bridget Jones's Diary
# The Bridges of Madison County
# The Spiderwick Chronicles
# The Smurfs 2
# V for Vendetta
# Mortal Kombat
# Shaft
# Star Trek: Insurrection
# Blade
# Nine Months
# Lost in Space
# Percy Jackson: Sea of Monsters
# The House with a Clock in Its Walls
# Mr. Popper's Penguins
# The Tourist
# Holes
# Insomnia
# Race to Witch Mountain
# 102 Dalmatians
# Alexander and the Terrible, Horrible, No Good, Very Bad Day
# Contraband
# The League of Extraordinary Gentlemen
# The Parent Trap
# Allegiant
# Herbie Fully Loaded
# The Manchurian Candidate
# X
# Lara Croft Tomb Raider: The Cradle of Life
# The Taking of Pelham 1 2 3
# Hannah Montana and Miley Cyrus: Best of Both Worlds Concert
# The Amityville Horror
# The Muppet Movie
# Friday the 13th
# A Dog's Purpose
# Jackass: The Movie
# Down to Earth
# Diary of a Wimpy Kid
# Miami Vice
# Bewitched
# Beavis and Butt
# A Nightmare on Elm Street
# Down and Out in Beverly Hills
# The Wolfman
# Ender's Game
# The Saint
# The Shaggy Dog
# Dora and the Lost City of Gold
# Resident Evil: Afterlife
# Brüno
# Superman III
# Jungle 2 Jungle
# Son of God
# Hellboy
# The Stepford Wives
# Dawn of the Dead
# Total Recall
# The Blue Lagoon
# RoboCop
# Anastasia
# Curious George
# Halloween
# Tomb Raider
# The Secret Life of Walter Mitty
# Baywatch
# Maze Runner: The Death Cure
# Fences
# Memoirs of a Geisha
# Dragnet
# 12 Monkeys
# The Man in the Iron Mask
# The Time Machine
# The Suicide Squad
# The BFG
# I Am Number Four
# The Jackal
# Spawn
# Starship Troopers
# Pet Sematary
# Assassin's Creed
# What Men Want
# The Omen
# The Woman in Black
# Evil Dead
# TMNT
# The Three Musketeers
# Sabrina
# Yours, Mine & Ours
# RED 2
# Unfaithful
# Diary of a Wimpy Kid: Rodrick Rules
# Blade: Trinity
# Star Trek V: The Final Frontier
# The Little Rascals
# South Park: Bigger, Longer & Uncut
# Ghost Rider: Spirit of Vengeance
# Atomic Blonde
# My Bloody Valentine
# Dennis the Menace
# Resident Evil: Apocalypse
# Muppets Most Wanted
# Naked Gun 33 1/3: The Final Insult
# The Hitchhiker's Guide to the Galaxy
# The Tale of Despereaux
# The Crow
# Resident Evil: Extinction
# Mighty Joe Young
# If I Stay
# K
# Overboard
# Angels in the Outfield
# Sommersby
# Popeye
# Are We Done Yet?
# Land of the Lost
# Diary of a Wimpy Kid: Dog Days
# Clifford the Big Red Dog
# Addams Family Values
# About Last Night
# Peter Pan
# Fat Albert
# The Preacher's Wife
# Kick
# Nim's Island
# When a Stranger Calls
# Poltergeist
# Warcraft
# The Toy
# Silent Hill
# The Rocketeer
# Goosebumps 2: Haunted Halloween
# The Brady Bunch Movie
# Walking Tall
# Five Feet Apart
# The Man from U.N.C.L.E.
# Bean
# The Giver
# Smurfs: The Lost Village
# Going in Style
# Timecop
# Red Dawn
# The Three Stooges
# The Sisterhood of the Traveling Pants 2
# The Beverly Hillbillies
# Speed Racer
# Prom Night
# Always
# Underdog
# Pokémon the Movie 2000
# Need for Speed
# Star Trek: Nemesis
# Biloxi Blues
# Death at a Funeral
# The Lizzie McGuire Movie
# Widows
# Resident Evil: Retribution
# Teenage Mutant Ninja Turtles III
# Fever Pitch
# Dirty Rotten Scoundrels
# Thir13en Ghosts
# Homeward Bound: The Incredible Journey
# The Hills Have Eyes
# The Angry Birds Movie 2
# Valerian and the City of a Thousand Planets
# The Mirror Has Two Faces
# The Water Horse
# Pee
# Paddington 2
# House on Haunted Hill
# Love, Simon
# Max Payne
# Three Fugitives
# Ghost in the Shell
# Peter Rabbit 2: The Runaway
# The Fly
# 2010: The Year We Make Contact
# Catwoman
# Resident Evil
# The Wild Thornberrys
# The Ladykillers
# Hitman
# 30 Days of Night
# The Texas Chainsaw Massacre: The Beginning
# Rugrats Go Wild
# The Grudge 2
# The Crazies
# The Sisterhood of the Traveling Pants
# Primary Colors
# The Ghost and the Darkness
# Surrogates
# Last Holiday
# Mighty Morphin Power Rangers: The Movie
# The Running Man
# Richie Rich
# Bedazzled
# The King's Man
# Sphere
# My Favorite Martian
# The Heartbreak Kid
# Recess: School's Out
# Taxi
# Death Race
# What a Girl Wants
# Mortal Kombat: Annihilation
# The Pink Panther 2
# The Mothman Prophecies
# The Indian in the Cupboard
# Children of Men
# The Hustle
# A Goofy Movie
# The Flintstones in Viva Rock Vegas
# Carrie
# The 5th Wave
# Judge Dredd
# Muppet Treasure Island
# My Dog Skip
# Everything, Everything
# Death Wish
# Closer
# The Punisher
# Dreamcatcher
# R.I.P.D.
# I Spy
# Matilda
# Street Fighter
# Halloween II
# Arthur
# Bad News Bears
# Homeward Bound II: Lost in San Francisco
# The Last House on the Left
# Annihilation
# Because of Winn
# Entourage
# Final Fantasy: The Spirits Within
# House of Wax
# The Shadow
# Paper Towns
# Quarantine
# From Hell
# Scott Pilgrim vs. the World
# A History of Violence
# The Eye
# The Great Muppet Caper
# The Secret Garden
# The Mortal Instruments: City of Bones
# The Princess Bride
# Mirrors
# Sgt. Bilko
# Point of No Return
# Madeline
# Teen Titans GO! To the Movies
# Mystery Men
# The Hate U Give
# The Fog
# Twilight Zone: The Movie
# Major Payne
# Zathura: A Space Adventure
# Romy and Michele's High School Reunion
# Priest
# The Mechanic
# The Stepfather
# James and the Giant Peach
# Kick
# Point Break
# Fathers' Day
# The Uninvited
# The Out
# Garfield: A Tail of Two Kitties
# Doom
# The Island of Dr. Moreau
# Blade Runner
# The Muppet Christmas Carol
# Cats
# The Jazz Singer
# Cloud Atlas
# Flash Gordon
# One Missed Call
# Resident Evil: The Final Chapter
# Winnie the Pooh
# The Host
# Harriet the Spy
# The Woman in Black 2: Angel of Death
# Ben
# Ramona and Beezus
# The Adventures of Rocky & Bullwinkle
# Shutter
# Æon Flux
# The Outsiders
# Other People's Money
# Nancy Drew
# The Muppets Take Manhattan
# Serenity
# My Father the Hero
# Dark Water
# The Woman in Red
# Midnight in the Garden of Good and Evil
# Invasion of the Body Snatchers
# Elektra
# Judy
# The Adventures of Huck Finn
# Don't Be Afraid of the Dark
# Around the World in 80 Days
# Tom and Huck
# The New Mutants
# Good Burger
# The Wicker Man
# The Losers
# Oscar
# Bulletproof Monk
# The Iron Giant
# The Care Bears Movie
# Ella Enchanted
# Beloved
# Frankie and Johnny
# Pure Luck
# The Borrowers
# Hitman: Agent 47
# Cousins
# Love Don't Cost a Thing
# The Big Wedding
# Friday the 13th Part 2
# Against All Odds
# Buck Rogers in the 25th Century
# Psycho
# Battlefield Earth
# A Very Brady Sequel
# Mr. Magoo
# Intersection
# Mechanic: Resurrection
# Tales from the Crypt: Demon Knight
# Flight of the Phoenix
# Flicka
# The X Files: I Want to Believe
# Super Mario Bros.
# The Hills Have Eyes 2
# Sleepless
# Diary of a Wimpy Kid: The Long Haul
# The Invisible
# The Circle
# The In
# Reno 911! Miami
# Jetsons: The Movie
# Pulse
# The Incredible Shrinking Woman
# Secret in Their Eyes
# The NeverEnding Story
# Flipper
# Assault on Precinct 13
# The Fly II
# Middle School: The Worst Years of My Life
# Prelude to a Kiss
# Unfaithfully Yours
# Breathless
# Fire in the Sky
# Altered States
# The Spirit
# Yu
# The Thing
# Timeline
# Beautiful Creatures
# Doug's 1st Movie
# The Producers
# Shaun the Sheep Movie
# The Secret World of Arrietty
# Tuck Everlasting
# I, Frankenstein
# Rollerball
# Blame It on Rio
# Paradise
# CHIPS
# An Ideal Husband
# The Four Feathers
# Fright Night
# That Darn Cat
# Love Affair
# Last Man Standing
# DuckTales the Movie: Treasure of the Lost Lamp
# Born Yesterday
# The Crow: City of Angels
# School for Scoundrels
# The Perks of Being a Wallflower
# The Postman
# Silent Hill: Revelation
# The NeverEnding Story II: The Next Chapter
# The Phantom
# Miracle on 34th Street
# Inkheart
# Freejack
# Diabolique
# Pokémon 3 the Movie: Spell of the Unown
# Flatliners
# Muppets from Space
# Original Sin
# Eye of the Beholder
# The Hitcher
# Tales from the Darkside: The Movie
# Howard the Duck
# Black Christmas
# The Getaway
# Mortal Engines
# Thomas and the Magic Railroad
# The Bonfire of the Vanities
# Superman IV: The Quest for Peace
# Bangkok Dangerous
# Monster Hunter
# Big Top Pee
# The Invasion
# Judy Moody and the Not Bummer Summer
# Miss Bala
# Solaris
# Get Carter
# The Nude Bomb
# The Vanishing
# Memoirs of an Invisible Man
# Supergirl
# The Wizard
# Josie and the Pussycats
# Virus
# Lord of the Flies
# Follow That Bird
# Cirque du Freak: The Vampire's Assistant
# Sin City: A Dame to Kill For
# Hey Arnold! The Movie
# Vice Versa
# Dredd
# Alfie
# The Mod Squad
# How to Eat Fried Worms
# To Be or Not to Be
# Wicker Park
# The Associate
# The Honeymooners
# Marvin's Room
# D.O.A.
# The Darkest Minds
# Bloodshot
# Before I Fall
# Barney's Great Adventure
# The Kitchen
# After
# Let Me In
# Sorority Row
# Brighton Beach Memoirs
# The Thirteenth Floor
# The Adventures of Elmo in Grouchland
# Lifeforce
# Wing Commander
# Moon Over Parador
# The Shipping News
# The Powerpuff Girls Movie
# The Smurfs and the Magic Flute
# The Man Who Loved Women
# Leave It to Beaver
# Narrow Margin
# Glengarry Glen Ross
# We're No Angels
# Jonah Hex
# The Witches
# House of the Dead
# A Little Princess
# Bratz
# Lassie
# Dudley Do
# Cloak and Dagger
# The Baby
# Digimon: The Movie
# Midnight Sun
# Bullet to the Head
# Village of the Damned
# Lost in Yonkers
# Body Parts
# Deadly Friend
# The Deep End
# Ratchet & Clank
# The Seeker: The Dark Is Rising
# Street Fighter: The Legend of Chun
# The Puppet Masters
# The Man with One Red Shoe
# The Bounty
# Care Bears Movie II: A New Generation
# 1984
# Something Wicked This Way Comes
# The Importance of Being Earnest
# Turbo: A Power Rangers Movie
# Downhill
# The Blob
# The Many Saints of Newark
# Whose Life Is It Anyway?
# Hoot
# Punisher: War Zone
# City of Ember
# Vampire Academy
# He
# The Crucible
# Buddy Buddy
# Cat People
# Willard
# Thunderbirds
# The Spectacular Now
# The Chipmunk Adventure
# Me and Earl and the Dying Girl
# The Gong Show Movie
# Teacher's Pet
# Six Degrees of Separation
# It's Kind of a Funny Story
# Little Miss Marker
# Ghost World
# Men Don't Leave
# American Splendor
# The Loft
# My Little Pony: The Movie
# The Transformers: The Movie
# Night of the Living Dead
# Bordello of Blood
# Sheena
# Batman: Mask of the Phantasm
# Aqua Teen Hunger Force Colon Movie Film for Theaters
# A Scanner Darkly
# Creator
# Monkey Shines
# Alone in the Dark
# Solo
# The Handmaid's Tale
# The Sun Is also a Star
# Rainbow Brite and the Star Stealer
# Invaders from Mars
# Just Visiting
# In the Name of the King: A Dungeon Siege Tale
# Absolutely Fabulous: The Movie
# King Kong Lives
# Snowpiercer
# McHale's Navy
# Gloria
# To Gillian on Her 37th Birthday
# Twin Peaks: Fire Walk with Me
# Tank Girl
# The Winslow Boy
# Trailer Park Boys: The Movie
# Barb Wire
# Batman: The Killing Joke
# A Monster Calls
# Tom and Jerry: The Great Escape
# The Bride
# Blood and Chocolate
# Jeffrey
# Talk Radio
# The Grand Seduction
# Veronica Mars
# Chloe
# Love! Valour! Compassion!
# The Warrior and the Sorceress
# Desperate Hours
# Kids in the Hall: Brain Candy
# Heathcliff: The Movie
# The Care Bears Adventure in Wonderland
# Bang Bang
# The Stupids
# Suspiria
# BloodRayne
# Double Dragon
# Noises Off...
# Blue Is the Warmest Colour
# Oldboy
# A Dog of Flanders
# Scenes from the Class Struggle in Beverly Hills
# Strangers with Candy
# Communion
# Hurlyburly
# Carnosaur
# Pokemon 4Ever: Celebi
# Steel
# After the Wedding
# Inhumans
# M. Butterfly
# A Cry in the Wild
# Little Nemo: Adventures in Slumberland
# GoBots: Battle of the Rock Lords
# Funny Games
# From Beyond
# Car 54, Where Are You?
# Dylan Dog: Dead of Night
# Nightwatch
# Nightflyers
# Wonderstruck
# Mystery Science Theater 3000: The Movie
# Cowboy Bebop: The Movie
# Watchers
# Simpatico
# The Miseducation of Cameron Post
# The Winter Guest
# Darker Than Night
# The Sum of Us
# Pokémon Heroes
# Rosencrantz & Guildenstern Are Dead
# The Shape of Things
# And God Created Woman
# American Buffalo
# SubUrbia
# The House of Yes
# Nancy Drew and the Hidden Staircase
# The Celestine Prophecy
# Noah's Arc: Jumping the Broom
# Tape
# The Browning Version
# DOA: Dead or Alive
# Body Snatchers
# Night of the Living Dead 3D
# Kingsglaive: Final Fantasy XV
# The Return of Swamp Thing
# We Are the Best!
# The Cherry Orchard
# Oleanna
# Wo zhi nv ren xin
# I Spit on Your Grave
# We Are What We Are
# Brenda Starr
# Gumby: The Movie
# The War at Home
# Madame Bovary
# Blood Ties
# Happy New Year
# Rurouni Kenshin Part I: Origins
# The Substance of Fire
# Maniac
# Tiger Eyes
# The Sweeney
# Silent Night
# The 24th Day
# 13 Sins
# War of the Buttons
# Radio Free Albemuth
# Human Capital
# Come Out and Play
# Postman Pat: The Movie
# Billy and Buddy
# I Spit on Your Grave 2
# Amityville: The Awakening

# %%
# adaptation_movie_page_info_list

# %% [markdown]
# # `adaptation_movie_info_df` from `adaptation_movie_page_info_list`

# %%
# #convert list of dict to df

adaptation_movie_info_df = pd.DataFrame(adaptation_movie_page_info_list)  
adaptation_movie_info_df.set_index('movie_title', inplace=True)

adaptation_movie_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 945 entries, The Avengers to Amityville: The Awakening
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   domestic_total_gross       945 non-null    int64
#  1   international_total_gross  945 non-null    int64
#  2   worldwide_total_gross      945 non-null    int64
#  3   domestic_opening           945 non-null    int64
#  4   budget                     945 non-null    int64
#  5   release_date               945 non-null    datetime64[ns]
#  6   runtime                    931 non-null    float64
#  7   distributor                945 non-null    object
#  8   genres                     945 non-null    object
#  9   rating                     774 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 81.2+ KB

# %% [markdown]
# # merge dfs: <br/>
# # `adaptation_movies_df` + `adaptation_movie_info_df`

# %%
# match this back up with the movie information collected from the table by merging  dataframes
adaptation_movies_df = adaptation_movies_df.merge(adaptation_movie_info_df, left_index=True, right_index=True)
adaptation_movies_df
# Out:
#                                                         link_stub rank  \
# 101 Dalmatians              /title/tt0115433/?ref_=bo_ge_table_49  149
# 102 Dalmatians              /title/tt0211181/?ref_=bo_ge_table_35  335
# 12 Monkeys                  /title/tt0114746/?ref_=bo_ge_table_85  385
# 13 Sins                     /title/tt2059171/?ref_=bo_ge_table_56  956
# 1984                         /title/tt0087803/?ref_=bo_ge_table_8  808
# ...                                                           ...  ...
# Yogi Bear                   /title/tt1302067/?ref_=bo_ge_table_32  232
# You've Got Mail             /title/tt0128853/?ref_=bo_ge_table_86  186
# Yours, Mine & Ours           /title/tt0443295/?ref_=bo_ge_table_5  405
# Zathura: A Space Adventure  /title/tt0406375/?ref_=bo_ge_table_77  577
# Æon Flux                     /title/tt0402022/?ref_=bo_ge_table_7  607
#
#                                            movie_title lifetime_gross  \
# 101 Dalmatians                          101 Dalmatians   $136,189,294
# 102 Dalmatians                          102 Dalmatians    $66,957,026
# 12 Monkeys                                  12 Monkeys    $57,141,459
# 13 Sins                                        13 Sins        $13,809
# 1984                                              1984     $8,430,492
# ...                                                ...            ...
# Yogi Bear                                    Yogi Bear   $100,246,011
# You've Got Mail                        You've Got Mail   $115,821,495
# Yours, Mine & Ours                  Yours, Mine & Ours    $53,412,862
# Zathura: A Space Adventure  Zathura: A Space Adventure    $29,258,869
# Æon Flux                                      Æon Flux    $25,874,337
#
#                            max_theaters opening_weekend opening_theathers  \
# 101 Dalmatians                    2,901     $33,504,025             2,794
# 102 Dalmatians                    2,704     $19,883,351             2,704
# 12 Monkeys                        1,629        $184,776                 3
# 13 Sins                              45          $9,261                45
# 1984                                295         $29,897                 1
# ...                                 ...             ...               ...
# Yogi Bear                         3,515     $16,411,322             3,515
# You've Got Mail                   2,948     $18,426,749             2,691
# Yours, Mine & Ours                3,210     $17,461,108             3,206
# Zathura: A Space Adventure        3,232     $13,427,872             3,223
# Æon Flux                          2,608     $12,661,112             2,608
#
#                            release_date_x  \
# 101 Dalmatians               Nov 27, 1996
# 102 Dalmatians               Nov 22, 2000
# 12 Monkeys                   Dec 29, 1995
# 13 Sins                      Apr 18, 2014
# 1984                         Dec 14, 1984
# ...                                   ...
# Yogi Bear                    Dec 17, 2010
# You've Got Mail              Dec 18, 1998
# Yours, Mine & Ours           Nov 23, 2005
# Zathura: A Space Adventure   Nov 11, 2005
# Æon Flux                      Dec 2, 2005
#
#                                                       distributor_x  \
# 101 Dalmatians              Walt Disney Studios Motion Pictures\n\n
# 102 Dalmatians              Walt Disney Studios Motion Pictures\n\n
# 12 Monkeys                                   Universal Pictures\n\n
# 13 Sins                                              RADiUS-TWC\n\n
# 1984                                 The Samuel Goldwyn Company\n\n
# ...                                                             ...
# Yogi Bear                                          Warner Bros.\n\n
# You've Got Mail                                    Warner Bros.\n\n
# Yours, Mine & Ours                           Paramount Pictures\n\n
# Zathura: A Space Adventure    Sony Pictures Entertainment (SPE)\n\n
# Æon Flux                                     Paramount Pictures\n\n
#
#                             domestic_total_gross  international_total_gross  \
# 101 Dalmatians                         136189294                  184500000
# 102 Dalmatians                          66957026                  116654745
# 12 Monkeys                              57141459                  111698000
# 13 Sins                                    13809                     813104
# 1984                                     8430492                    8430492
# ...                                          ...                        ...
# Yogi Bear                              100246011                  103263363
# You've Got Mail                        115821495                  135000000
# Yours, Mine & Ours                      53412862                   19250061
# Zathura: A Space Adventure              29258869                   35820235
# Æon Flux                                25874337                   27447336
#
#                             worldwide_total_gross  domestic_opening    budget  \
# 101 Dalmatians                          320689294          33504025         0
# 102 Dalmatians                          183611771          19883351  85000000
# 12 Monkeys                              168839459            184776         0
# 13 Sins                                    826913              9261         0
# 1984                                            0             29897         0
# ...                                           ...               ...       ...
# Yogi Bear                               203509374          16411322  80000000
# You've Got Mail                         250821495          18426749  65000000
# Yours, Mine & Ours                       72662923          17461108  45000000
# Zathura: A Space Adventure               65079104          13427872  65000000
# Æon Flux                                 53321673          12661112  62000000
#
#                            release_date_y  runtime  \
# 101 Dalmatians                 1996-11-27    103.0
# 102 Dalmatians                 2000-11-22    100.0
# 12 Monkeys                     1995-12-29    129.0
# 13 Sins                        2014-04-11     93.0
# 1984                           1984-12-14    113.0
# ...                                   ...      ...
# Yogi Bear                      2010-12-17     81.0
# You've Got Mail                1998-12-18    119.0
# Yours, Mine & Ours             2005-11-23     88.0
# Zathura: A Space Adventure     2005-11-11    101.0
# Æon Flux                       2005-12-01     93.0
#
#                                                   distributor_y  \
# 101 Dalmatians              Walt Disney Studios Motion Pictures
# 102 Dalmatians              Walt Disney Studios Motion Pictures
# 12 Monkeys                                   Universal Pictures
# 13 Sins                                              RADiUS-TWC
# 1984                                 The Samuel Goldwyn Company
# ...                                                         ...
# Yogi Bear                                          Warner Bros.
# You've Got Mail                                    Warner Bros.
# Yours, Mine & Ours                           Paramount Pictures
# Zathura: A Space Adventure    Sony Pictures Entertainment (SPE)
# Æon Flux                                     Paramount Pictures
#
#                                                                        genres  \
# 101 Dalmatians                               Adventure, Comedy, Crime, Family
# 102 Dalmatians                                      Adventure, Comedy, Family
# 12 Monkeys                                          Mystery, Sci-Fi, Thriller
# 13 Sins                                                      Horror, Thriller
# 1984                                                            Drama, Sci-Fi
# ...                                                                       ...
# Yogi Bear                                Adventure, Animation, Comedy, Family
# You've Got Mail                                        Comedy, Drama, Romance
# Yours, Mine & Ours                                    Comedy, Family, Romance
# Zathura: A Space Adventure  Action, Adventure, Comedy, Family, Fantasy, Sc...
# Æon Flux                                  Action, Adventure, Sci-Fi, Thriller
#
#                            rating
# 101 Dalmatians               None
# 102 Dalmatians               None
# 12 Monkeys                      R
# 13 Sins                         R
# 1984                         None
# ...                           ...
# Yogi Bear                      PG
# You've Got Mail                PG
# Yours, Mine & Ours             PG
# Zathura: A Space Adventure     PG
# Æon Flux                    PG-13
#
# [901 rows x 19 columns]

# %%
# movie df to start EDA
adaptation_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 901 entries, 101 Dalmatians to Æon Flux
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   link_stub                  901 non-null    object
#  1   rank                       901 non-null    object
#  2   movie_title                901 non-null    object
#  3   lifetime_gross             901 non-null    object
#  4   max_theaters               901 non-null    object
#  5   opening_weekend            901 non-null    object
#  6   opening_theathers          901 non-null    object
#  7   release_date_x             901 non-null    object
#  8   distributor_x              901 non-null    object
#  9   domestic_total_gross       901 non-null    int64
#  10  international_total_gross  901 non-null    int64
#  11  worldwide_total_gross      901 non-null    int64
#  12  domestic_opening           901 non-null    int64
#  13  budget                     901 non-null    int64
#  14  release_date_y             901 non-null    datetime64[ns]
#  15  runtime                    888 non-null    float64
#  16  distributor_y              901 non-null    object
#  17  genres                     901 non-null    object
#  18  rating                     734 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(12)
# memory usage: 140.8+ KB

# %%
# picke df 
adaptation_movies_all_df = adaptation_movies_df
adaptation_movies_all_df.to_pickle('adaptation_movies_all_df.pkl')

# %%
# save to csv
adaptation_movies_df.to_csv(r'/Users/sandraparedes/Dropbox/Mac/Downloads/adaptation_movies_all_df.csv', index=False)
