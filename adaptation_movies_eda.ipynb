# %% [markdown]
# # Exporting American Movie Box Office Hits
#
# ### boxofficemojo.com exploratory data analysis

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
import dateutil.parser
import time
import random

# %%
# movies_df = pd.read_pickle('adaptation_movies_df.pkl')
df = pd.read_csv('adaptation_movies_df.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   link_stub                  901 non-null    object
#  1   rank                       901 non-null    int64
#  2   movie_title                901 non-null    object
#  3   lifetime_gross             901 non-null    object
#  4   max_theaters               901 non-null    object
#  5   opening_weekend            901 non-null    object
#  6   opening_theathers          901 non-null    object
#  7   release_date_x             901 non-null    object
#  8   distributor_x              901 non-null    object
#  9   domestic_total_gross       901 non-null    int64
#  10  international_total_gross  901 non-null    int64
#  11  worldwide_total_gross      901 non-null    int64
#  12  domestic_opening           901 non-null    int64
#  13  budget                     901 non-null    int64
#  14  release_date_y             901 non-null    object
#  15  runtime                    888 non-null    float64
#  16  distributor_y              899 non-null    object
#  17  genres                     901 non-null    object
#  18  rating                     734 non-null    object
# dtypes: float64(1), int64(6), object(12)
# memory usage: 133.9+ KB

# %%
# drop duplicate columns 
df.drop(columns=['lifetime_gross',
                        'opening_weekend',
                        'release_date_x',
                        'distributor_x'],inplace=True)
df.head(2)
# Out:
#                                link_stub  rank     movie_title max_theaters  \
# 0  /title/tt0115433/?ref_=bo_ge_table_49   149  101 Dalmatians        2,901
# 1  /title/tt0211181/?ref_=bo_ge_table_35   335  102 Dalmatians        2,704
#
#   opening_theathers  domestic_total_gross  international_total_gross  \
# 0             2,794             136189294                  184500000
# 1             2,704              66957026                  116654745
#
#    worldwide_total_gross  domestic_opening    budget release_date_y  runtime  \
# 0              320689294          33504025         0     1996-11-27    103.0
# 1              183611771          19883351  85000000     2000-11-22    100.0
#
#                          distributor_y                            genres  \
# 0  Walt Disney Studios Motion Pictures  Adventure, Comedy, Crime, Family
# 1  Walt Disney Studios Motion Pictures         Adventure, Comedy, Family
#
#   rating
# 0    NaN
# 1    NaN

# %%
# rename columns
df = df.rename({'distributor_y':'distributor', 'release_date_y':'release_date'}, axis=1)

df.head(2)
# Out:
#                                link_stub  rank     movie_title max_theaters  \
# 0  /title/tt0115433/?ref_=bo_ge_table_49   149  101 Dalmatians        2,901
# 1  /title/tt0211181/?ref_=bo_ge_table_35   335  102 Dalmatians        2,704
#
#   opening_theathers  domestic_total_gross  international_total_gross  \
# 0             2,794             136189294                  184500000
# 1             2,704              66957026                  116654745
#
#    worldwide_total_gross  domestic_opening    budget release_date  runtime  \
# 0              320689294          33504025         0   1996-11-27    103.0
# 1              183611771          19883351  85000000   2000-11-22    100.0
#
#                            distributor                            genres  \
# 0  Walt Disney Studios Motion Pictures  Adventure, Comedy, Crime, Family
# 1  Walt Disney Studios Motion Pictures         Adventure, Comedy, Family
#
#   rating
# 0    NaN
# 1    NaN

# %%
# strip commas 
df = df.replace(',','', regex=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   link_stub                  901 non-null    object
#  1   rank                       901 non-null    int64
#  2   movie_title                901 non-null    object
#  3   max_theaters               901 non-null    object
#  4   opening_theathers          901 non-null    object
#  5   domestic_total_gross       901 non-null    int64
#  6   international_total_gross  901 non-null    int64
#  7   worldwide_total_gross      901 non-null    int64
#  8   domestic_opening           901 non-null    int64
#  9   budget                     901 non-null    int64
#  10  release_date               901 non-null    object
#  11  runtime                    888 non-null    float64
#  12  distributor                899 non-null    object
#  13  genres                     901 non-null    object
#  14  rating                     734 non-null    object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 105.7+ KB

# %%
df.head(2)
# Out:
#                                link_stub  rank     movie_title max_theaters  \
# 0  /title/tt0115433/?ref_=bo_ge_table_49   149  101 Dalmatians         2901
# 1  /title/tt0211181/?ref_=bo_ge_table_35   335  102 Dalmatians         2704
#
#   opening_theathers  domestic_total_gross  international_total_gross  \
# 0              2794             136189294                  184500000
# 1              2704              66957026                  116654745
#
#    worldwide_total_gross  domestic_opening    budget release_date  runtime  \
# 0              320689294          33504025         0   1996-11-27    103.0
# 1              183611771          19883351  85000000   2000-11-22    100.0
#
#                            distributor                         genres rating
# 0  Walt Disney Studios Motion Pictures  Adventure Comedy Crime Family    NaN
# 1  Walt Disney Studios Motion Pictures        Adventure Comedy Family    NaN

# %%
# change theather data to int32

# df.astype({'max_theaters': 'int64'}).dtypes
# df.astype({'opening_theathers': 'int64'}).dtypes

# %%
# sort by domestic_total_gross instead of rank
df.sort_values('domestic_total_gross', ascending=False, inplace=True)
df.head(10)
# Out:
#                                  link_stub  rank  \
# 702   /title/tt6105098/?ref_=bo_ge_table_6     6
# 637   /title/tt0468569/?ref_=bo_ge_table_7     7
# 78    /title/tt2771200/?ref_=bo_ge_table_8     8
# 60    /title/tt2395427/?ref_=bo_ge_table_9     9
# 638  /title/tt1345836/?ref_=bo_ge_table_10    10
# 120  /title/tt4154664/?ref_=bo_ge_table_11    11
# 681  /title/tt1951264/?ref_=bo_ge_table_12    12
# 893  /title/tt0451279/?ref_=bo_ge_table_13    13
# 324  /title/tt1300854/?ref_=bo_ge_table_14    14
# 117  /title/tt3498820/?ref_=bo_ge_table_15    15
#
#                          movie_title max_theaters opening_theathers  \
# 702                    The Lion King         4802              4725
# 637                  The Dark Knight         4366              4366
# 78              Beauty and the Beast         4210              4210
# 60           Avengers: Age of Ultron         4276              4276
# 638            The Dark Knight Rises         4404              4404
# 120                   Captain Marvel         4310              4310
# 681  The Hunger Games: Catching Fire         4163              4163
# 893                     Wonder Woman         4165              4165
# 324                       Iron Man 3         4253              4253
# 117       Captain America: Civil War         4226              4226
#
#      domestic_total_gross  international_total_gross  worldwide_total_gross  \
# 702             543638043                 1119261396             1662899439
# 637             534987076                  471115201             1006102277
# 78              504481165                  769095055             1273576220
# 60              459005868                  943803672             1402809540
# 638             448149584                  633003513             1081153097
# 120             426829839                  701633133             1128462972
# 681             424668047                  440343699              865011746
# 893             412845172                  410009114              822854286
# 324             409013994                  805797258             1214811252
# 117             408084349                  745253147             1153337496
#
#      domestic_opening     budget release_date  runtime  \
# 702         191770759  260000000   2019-07-11    118.0
# 637         158411483  185000000   2008-07-16    152.0
# 78          174750616  160000000   2017-03-16    129.0
# 60          191271109  250000000   2015-04-22    141.0
# 638         160887295  250000000   2012-07-19    164.0
# 120         153433423  160000000   2019-03-06    123.0
# 681         158074286  130000000   2013-11-15    146.0
# 893         103251471  149000000   2017-05-30    141.0
# 324         174144585  200000000   2013-04-24    130.0
# 117         179139142  250000000   2016-04-27    147.0
#
#                              distributor  \
# 702  Walt Disney Studios Motion Pictures
# 637                         Warner Bros.
# 78   Walt Disney Studios Motion Pictures
# 60   Walt Disney Studios Motion Pictures
# 638                         Warner Bros.
# 120  Walt Disney Studios Motion Pictures
# 681                            Lionsgate
# 893                         Warner Bros.
# 324  Walt Disney Studios Motion Pictures
# 117  Walt Disney Studios Motion Pictures
#
#                                        genres rating
# 702  Adventure Animation Drama Family Musical     PG
# 637               Action Crime Drama Thriller  PG-13
# 78   Adventure Family Fantasy Musical Romance     PG
# 60                    Action Adventure Sci-Fi  PG-13
# 638                        Action Crime Drama  PG-13
# 120                   Action Adventure Sci-Fi  PG-13
# 681    Action Adventure Drama Sci-Fi Thriller  PG-13
# 893       Action Adventure Fantasy Sci-Fi War  PG-13
# 324                   Action Adventure Sci-Fi  PG-13
# 117                   Action Adventure Sci-Fi  PG-13

# %%
# # shift column 'Name' to first position
# first_column = df.pop('Name')
  
# # insert column using insert(position,column_name,
# # first_column) function
# df.insert(0, 'Name', first_column)
  
# print()
# print("After Shifting column to first position")
# display(df)

# %%
# movie link_stub to last column
link_stub_col = df.pop('link_stub')
df.insert(14, 'link_stub', link_stub_col)

# %%
domestic_total_gross_col = df.pop('domestic_total_gross')
df.insert(0, 'domestic_total_gross', domestic_total_gross_col)
df.head(2)
# Out:
#      domestic_total_gross  rank      movie_title max_theaters  \
# 702             543638043     6    The Lion King         4802
# 637             534987076     7  The Dark Knight         4366
#
#     opening_theathers  international_total_gross  worldwide_total_gross  \
# 702              4725                 1119261396             1662899439
# 637              4366                  471115201             1006102277
#
#      domestic_opening     budget release_date  runtime  \
# 702         191770759  260000000   2019-07-11    118.0
# 637         158411483  185000000   2008-07-16    152.0
#
#                              distributor  \
# 702  Walt Disney Studios Motion Pictures
# 637                         Warner Bros.
#
#                                        genres rating  \
# 702  Adventure Animation Drama Family Musical     PG
# 637               Action Crime Drama Thriller  PG-13
#
#                                 link_stub
# 702  /title/tt6105098/?ref_=bo_ge_table_6
# 637  /title/tt0468569/?ref_=bo_ge_table_7

# %%
df.reset_index(drop=True)
# Out:
#      domestic_total_gross  rank                movie_title max_theaters  \
# 0               543638043     6              The Lion King         4802
# 1               534987076     7            The Dark Knight         4366
# 2               504481165     8       Beauty and the Beast         4210
# 3               459005868     9    Avengers: Age of Ultron         4276
# 4               448149584    10      The Dark Knight Rises         4404
# ..                    ...   ...                        ...          ...
# 896                  2638   960          Come Out and Play           10
# 897                  1519   961     Postman Pat: The Movie            2
# 898                   894   962            Billy and Buddy            2
# 899                   809   963     I Spit on Your Grave 2            1
# 900                   742   964  Amityville: The Awakening           10
#
#     opening_theathers  international_total_gross  worldwide_total_gross  \
# 0                4725                 1119261396             1662899439
# 1                4366                  471115201             1006102277
# 2                4210                  769095055             1273576220
# 3                4276                  943803672             1402809540
# 4                4404                  633003513             1081153097
# ..                ...                        ...                    ...
# 896                10                     269097                 271735
# 897                 2                    7100936                7102455
# 898                 -                   17399159               17400053
# 899                 1                     677795                 678604
# 900                10                    8481255                8481997
#
#      domestic_opening     budget release_date  runtime  \
# 0           191770759  260000000   2019-07-11    118.0
# 1           158411483  185000000   2008-07-16    152.0
# 2           174750616  160000000   2017-03-16    129.0
# 3           191271109  250000000   2015-04-22    141.0
# 4           160887295  250000000   2012-07-19    164.0
# ..                ...        ...          ...      ...
# 896              1600          0   2013-03-22    105.0
# 897              1254          0   2014-05-23     88.0
# 898                 0          0   2013-02-27     82.0
# 899               441          0   2013-09-05    106.0
# 900               742          0   2017-07-20     87.0
#
#                              distributor  \
# 0    Walt Disney Studios Motion Pictures
# 1                           Warner Bros.
# 2    Walt Disney Studios Motion Pictures
# 3    Walt Disney Studios Motion Pictures
# 4                           Warner Bros.
# ..                                   ...
# 896         Cinedigm Entertainment Group
# 897                       Shout! Factory
# 898                        Distrib Films
# 899                     Anchor Bay Films
# 900                      Dimension Films
#
#                                        genres rating  \
# 0    Adventure Animation Drama Family Musical     PG
# 1                 Action Crime Drama Thriller  PG-13
# 2    Adventure Family Fantasy Musical Romance     PG
# 3                     Action Adventure Sci-Fi  PG-13
# 4                          Action Crime Drama  PG-13
# ..                                        ...    ...
# 896                                    Horror      R
# 897                   Animation Comedy Family    NaN
# 898                             Comedy Family    NaN
# 899                           Horror Thriller      R
# 900                           Horror Thriller  PG-13
#
#                                  link_stub
# 0     /title/tt6105098/?ref_=bo_ge_table_6
# 1     /title/tt0468569/?ref_=bo_ge_table_7
# 2     /title/tt2771200/?ref_=bo_ge_table_8
# 3     /title/tt2395427/?ref_=bo_ge_table_9
# 4    /title/tt1345836/?ref_=bo_ge_table_10
# ..                                     ...
# 896  /title/tt2341664/?ref_=bo_ge_table_60
# 897  /title/tt2062622/?ref_=bo_ge_table_61
# 898  /title/tt2538654/?ref_=bo_ge_table_62
# 899  /title/tt2537176/?ref_=bo_ge_table_63
# 900  /title/tt1935897/?ref_=bo_ge_table_64
#
# [901 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 901 entries, 702 to 44
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   domestic_total_gross       901 non-null    int64
#  1   rank                       901 non-null    int64
#  2   movie_title                901 non-null    object
#  3   max_theaters               901 non-null    object
#  4   opening_theathers          901 non-null    object
#  5   international_total_gross  901 non-null    int64
#  6   worldwide_total_gross      901 non-null    int64
#  7   domestic_opening           901 non-null    int64
#  8   budget                     901 non-null    int64
#  9   release_date               901 non-null    object
#  10  runtime                    888 non-null    float64
#  11  distributor                899 non-null    object
#  12  genres                     901 non-null    object
#  13  rating                     734 non-null    object
#  14  link_stub                  901 non-null    object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 112.6+ KB

# %%
# picke df 
clean_df = df 
clean_df.to_pickle('clean_df.pkl')

# %%
# save to csv
clean_df.to_csv(r'/Users/sandraparedes/Dropbox/Mac/Downloads/clean_df.csv', index=False)
