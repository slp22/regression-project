# %% [markdown]
# # Exporting American Movie Box Office Hits
#
# ### boxofficemojo.com data acquisition

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
import dateutil.parser
import time
import random

# %%
offset = 0
base_url = 'https://www.boxofficemojo.com/genre/sg1625223425/?offset='

movies_urls = []

for url in range(10):
    movies_urls.append(base_url + str(offset))
    offset = offset + 100

# %%
def scrape_movies(url, movies_data):
#     url = 'https://www.boxofficemojo.com/genre/sg1625223425/?ref_=bo_gs_table_10'
    response = requests.get(url)
    status = response.status_code
    if status == 200:
        print('Status is 200')
        page = response.text
        soup = bs(page, "lxml")
        table = soup.find("table")
        rows = [row for row in table.find_all('tr')] 
        for row in rows:
            movies_data.append(row)
    else:
        print(f"Oops! Received status code {status}")
        return None
    
movies_data = []

for movie_url in movies_urls:
    scrape_movies(movie_url, movies_data)
    
print(movies_data)
# Out:
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# Status is 200
# [<tr><th class="a-text-right mojo-field-type-rank mojo-sortable-column a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title mojo-sortable-column a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money mojo-sort-column mojo-sortable-column mojo-estimatable a-nowrap"><a class="a-link-normal a-nowrap" href="?offset=0&amp;sort=grossToDate&amp;sortDir=asc&amp;ref_=bo_ge__resort#table" title="Lifetime Gross"><span class="a-color-state">Lifetime Gross</span><span class="a-letter-space"></span><span class="icon aok-relative"><i class="a-icon a-icon-expand" role="presentation"></i></span></a></th><th class="a-text-right mojo-field-type-positive_integer mojo-sortable-column a-nowrap"><a class="a-link-normal a-nowrap" href="?offset=0&amp;sort=maxNumTheaters&amp;ref_=bo_ge__resort#table" title="Max Theaters">Max Theaters<span class="a-letter-space"></span><span class="icon aok-relative"><i class="a-icon a-icon-expand table-sort-desc-placeholder" role="presentation"></i><i class="a-icon a-icon-collapse table-sort-asc-placeholder" role="presentation"></i></span></a></th><th class="a-text-right mojo-field-type-money mojo-sortable-column a-nowrap"><a class="a-link-normal a-nowrap" href="?offset=0&amp;sort=openingWeekendGross&amp;ref_=bo_ge__resort#table" title="Opening">Opening<span class="a-letter-space"></span><span class="icon aok-relative"><i class="a-icon a-icon-expand table-sort-desc-placeholder" role="presentation"></i><i class="a-icon a-icon-collapse table-sort-asc-placeholder" role="presentation"></i></span></a></th><th class="a-text-right mojo-field-type-positive_integer mojo-sortable-column a-nowrap"><a class="a-link-normal a-nowrap" href="?offset=0&amp;sort=openingNumTheaters&amp;ref_=bo_ge__resort#table" title="Open Th">Open Th<span class="a-letter-space"></span><span class="icon aok-relative"><i class="a-icon a-icon-expand table-sort-desc-placeholder" role="presentation"></i><i class="a-icon a-icon-collapse table-sort-asc-placeholder" role="presentation"></i></span></a></th><th class="a-text-left mojo-field-type-date mojo-sortable-column a-nowrap"><a class="a-link-normal a-nowrap" href="?offset=0&amp;sort=releaseDate&amp;ref_=bo_ge__resort#table" title="Release Date">Release Date<span class="a-letter-space"></span><span class="icon aok-relative"><i class="a-icon a-icon-expand table-sort-desc-placeholder" role="presentation"></i><i class="a-icon a-icon-collapse table-sort-asc-placeholder" role="presentation"></i></span></a></th><th class="a-text-left mojo-field-type-release_studios mojo-sortable-column a-nowrap"><span title="Distributor">Distributor</span>
# </th></tr>, <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_ge_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable">$858,373,000</td><td class="a-text-right mojo-field-type-positive_integer">4,662</td><td class="a-text-right mojo-field-type-money">$357,115,007</td><td class="a-text-right mojo-field-type-positive_integer">4,662</td><td class="a-text-left mojo-field-type-date a-nowrap"><a class="a-link-normal" href="/date/2019-04-26/?ref_=bo_ge_table_1">Apr 26, 2019</a></td><td class="a-text-left mojo-field-type-release_studios"><a class="a-link-normal" href="https://pro.imdb.com/company/co0226183/boxoffice/?view=releases&amp;ref_=mojo_ge_table_1&amp;rf=mojo_ge_table_1" rel="noopener" target="_blank">Walt Disney Studios Motion Pictures<svg class="mojo-new-window-svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
# <path d="M24,15.57251l3,3V23.5A3.50424,3.50424,0,0,1,23.5,27H8.5A3.50424,3.50424,0,0,1,5,23.5V8.5A3.50424,3.50424,0,0,1,8.5,5h4.92755l3,3H8.5a.50641.50641,0,0,0-.5.5v15a.50641.50641,0,0,0,.5.5h15a.50641.50641,0,0,0,.5-.5ZM19.81952,8.56372,12.8844,17.75a.49989.49989,0,0,0,.04547.65479l.66534.66528a.49983.49983,0,0,0,.65479.04553l9.18628-6.93518,2.12579,2.12585a.5.5,0,0,0,.84741-.27526l1.48273-9.35108a.50006.50006,0,0,0-.57214-.57214L17.969,5.59058a.5.5,0,0,0-.27526.84741Z"></path>
# </svg></a></td></tr>, <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">2</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt10872600/?ref_=bo_ge_table_2">Spider-Man: No Way Home</a></td><td class="a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable">$789,170,954</td><td class="a-text-right mojo-field-type-positive_integer">4,336</td><td class="a-text-right mojo-field-type-money">$260,138,569</td><td class="a-text-right mojo-field-type-positive_integer">4,336</td><td class="a-text-left mojo-field-type-date a-nowrap"><a class="a-link-normal" href="/date/2021-12-17/?ref_=bo_ge_table_2">Dec 17, 2021</a></td><td class="a-text-left mojo-field-type-release_studios"><a class="a-link-normal" href="https://pro.imdb.com/company/co0026545/boxoffice/?view=releases&amp;ref_=mojo_ge_table_2&amp;rf=mojo_ge_table_2" rel="noopener" target="_blank">Sony Pictures Entertainment (SPE)<svg class="mojo-new-window-svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
# <path d="M24,15.57251l3,3V23.5A3.50424,3.50424,0,0,1,23.5,27H8.5A3.50424,3.50424,0,0,1,5,23.5V8.5A3.50424,3.50424,0,0,1,8.5,5h4.92755l3,3H8.5a.50641.50641,0,0,0-.5.5v15a.50641.50641,0,0,0,.5.5h15a.50641.50641,0,0,0,.5-.5ZM19.81952,8.56372,12.8844,17.75a.49989.49989,0,0,0,.04547.65479l.66534.66528a.49983.49983,0,0,0,.65479.04553l9.18628-6.93518,2.12579,2.12585a.5.5,0,0,0,.84741-.27526l1.48273-9.35108a.50006.50006,0,0,0-.57214-.57214L17.969,5.59058a.5.5,0,0,0-.27526.84741Z"></path>
# </svg></a></td></tr>, <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">3</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1825683/?ref_=bo_ge_table_3">Black Panther</a></td><td class="a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable">$700,059,566</td><td class="a-text-right mojo-field-type-positive_integer">4,084</td><td class="a-text-right mojo-field-type-money">$202,003,951</td><td class="a-text-right mojo-field-type-positive_integer">4,020</td><td class="a-text-left mojo-field-type-date a-nowrap"><a class="a-link-normal" href="/date/2018-02-16/?ref_=bo_ge_table_3">Feb 16, 2018</a></td><td class="a-text-left mojo-field-type-release_studios"><a class="a-link-normal" href="https://pro.imdb.com/company/co0226183/boxoffice/?view=releases&amp;ref_=mojo_ge_table_3&amp;rf=mojo_ge_table_3" rel="noopener" target="_blank">Walt Disney Studios Motion Pictures<svg class="mojo-new-window-svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
# <path d="M24,15.57251l3,3V23.5A3.50424,3.50424,0,0,1,23.5,27H8.5A3.50424,3.50424,0,0,1,5,23.5V8.5A3.50424,3.50424,0,0,1,8.5,5h4.92755l3,3H8.5a.50641.50641,0,0,0-.5.5v15a.50641.50641,0,0,0,.5.5h15a.50641.50641,0,0,0,.5-.5ZM19.81952,8.56372,12.8844,17.75a.49989.49989,0,0,0,.04547.65479l.66534.66528a.49983.49983,0,0,0,.65479.04553l9.18628-6.93518,2.12579,2.12585a.5.5,0,0,0,.84741-.27526l1.48273-9.35108a.50006.50006,0,0,0-.57214-.57214L17.969,5.59058a.5.5,0,0,0-.27526.84741Z"></path>
# </svg></a></td></tr>, <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">4</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154756/?ref_=bo_ge_table_4">Avengers: Infinity War</a></td><td class="a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable">$678,815,482</td><td class="a-text-right mojo-field-type-positive_integer">4,474</td><td class="a-text-right mojo-field-type-money">$257,698,183</td><td class="a-text-right mojo-field-type-positive_integer">4,474</td><td class="a-text-left mojo-field-type-date a-nowrap"><a class="a-link-normal" href="/date/
td><td class="a-text-right mojo-field-type-positive_integer">10</td><td class="a-text-right mojo-field-type-money">$742</td><td class="a-text-right mojo-field-type-positive_integer">10</td><td class="a-text-left mojo-field-type-date a-nowrap"><a class="a-link-normal" href="/date/2017-10-28/?ref_=bo_ge_table_64">Oct 28, 2017</a></td><td class="a-text-left mojo-field-type-release_studios">-</td></tr>]

# %%
# print(movies_data)
# type(movies_data[0])
# print(movies_data[1].prettify())

movies_data.pop(0)

movies_dict = {}


# try:
#     item = someList[index]
# except IndexError:
#     # handle out-ot-range index


for row in movies_data:
    items = row.find_all('td')
    try:
        link = items[1].find('a')
        title, url = link.text, link['href']
        movies_dict[title] = [url] + [i.text for i in items]
    except IndexError:
        continue
        

print(movies_dict)
# Out:
# {'The Avengers': ['/title/tt0118661/?ref_=bo_ge_table_29', '629', 'The Avengers', '$23,384,939', '2,466', '$10,305,957', '2,466', 'Aug 14, 1998', 'Warner Bros.\n\n'], 'The Lion King': ['/title/tt6105098/?ref_=bo_ge_table_6', '6', 'The Lion King', '$543,638,043', '4,802', '$191,770,759', '4,725', 'Jul 19, 2019', 'Walt Disney Studios Motion Pictures\n\n'], 'The Dark Knight': ['/title/tt0468569/?ref_=bo_ge_table_7', '7', 'The Dark Knight', '$533,345,358', '4,366', '$158,411,483', '4,366', 'Jul 18, 2008', 'Warner Bros.\n\n'], 'Beauty and the Beast': ['/title/tt2771200/?ref_=bo_ge_table_8', '8', 'Beauty and the Beast', '$504,014,165', '4,210', '$174,750,616', '4,210', 'Mar 17, 2017', 'Walt Disney Studios Motion Pictures\n\n'], 'Avengers: Age of Ultron': ['/title/tt2395427/?ref_=bo_ge_table_9', '9', 'Avengers: Age of Ultron', '$459,005,868', '4,276', '$191,271,109', '4,276', 'May 1, 2015', 'Walt Disney Studios Motion Pictures\n\n'], 'The Dark Knight Rises': ['/title/tt1345836/?ref_=bo_ge_table_10', '10', 'The Dark Knight Rises', '$448,139,099', '4,404', '$160,887,295', '4,404', 'Jul 20, 2012', 'Warner Bros.\n\n'], 'Captain Marvel': ['/title/tt4154664/?ref_=bo_ge_table_11', '11', 'Captain Marvel', '$426,829,839', '4,310', '$153,433,423', '4,310', 'Mar 8, 2019', 'Walt Disney Studios Motion Pictures\n\n'], 'The Hunger Games: Catching Fire': ['/title/tt1951264/?ref_=bo_ge_table_12', '12', 'The Hunger Games: Catching Fire', '$424,668,047', '4,163', '$158,074,286', '4,163', 'Nov 22, 2013', 'Lionsgate\n\n'], 'Wonder Woman': ['/title/tt0451279/?ref_=bo_ge_table_13', '13', 'Wonder Woman', '$412,563,408', '4,165', '$103,251,471', '4,165', 'Jun 2, 2017', 'Warner Bros.\n\n'], 'Iron Man 3': ['/title/tt1300854/?ref_=bo_ge_table_14', '14', 'Iron Man 3', '$409,013,994', '4,253', '$174,144,585', '4,253', 'May 3, 2013', 'Walt Disney Studios Motion Pictures\n\n'], 'Captain America: Civil War': ['/title/tt3498820/?ref_=bo_ge_table_15', '15', 'Captain America: Civil War', '$408,084,349', '4,226', '$179,139,142', '4,226', 'May 6, 2016', 'Walt Disney Studios Motion Pictures\n\n'], 'The Hunger Games': ['/title/tt1392170/?ref_=bo_ge_table_16', '16', 'The Hunger Games', '$408,010,692', '4,137', '$152,535,747', '4,137', 'Mar 23, 2012', 'Lionsgate\n\n'], 'Spider-Man': ['/title/tt0145487/?ref_=bo_ge_table_17', '17', 'Spider-Man', '$403,706,375', '3,876', '$114,844,116', '3,615', 'May 3, 2002', 'Sony Pictures Entertainment (SPE)\n\n'], 'Transformers: Revenge of the Fallen': ['/title/tt1055369/?ref_=bo_ge_table_18', '18', 'Transformers: Revenge of the Fallen', '$402,111,870', '4,293', '$108,966,307', '4,234', 'Jun 24, 2009', 'DreamWorks\n\n'], 'Spider-Man: Far from Home': ['/title/tt6320628/?ref_=bo_ge_table_19', '19', 'Spider-Man: Far from Home', '$390,532,085', '4,634', '$92,579,212', '4,634', 'Jul 2, 2019', 'Sony Pictures Entertainment (SPE)\n\n'], 'Guardians of the Galaxy Vol. 2': ['/title/tt3896198/?ref_=bo_ge_table_20', '20', 'Guardians of the Galaxy Vol. 2', '$389,813,101', '4,347', '$146,510,104', '4,347', 'May 5, 2017', 'Walt Disney Studios Motion Pictures\n\n'], 'Harry Potter and the Deathly Hallows: Part 2': ['/title/tt1201607/?ref_=bo_ge_table_21', '21', 'Harry Potter and the Deathly Hallows: Part 2', '$381,011,219', '4,375', '$169,189,427', '4,375', 'Jul 15, 2011', 'Warner Bros.\n\n'], 'Spider-Man 2': ['/title/tt0316654/?ref_=bo_ge_table_22', '22', 'Spider-Man 2', '$373,585,825', '4,166', '$88,156,227', '4,152', 'Jun 30, 2004', 'Sony Pictures Entertainment (SPE)\n\n'], 'The Jungle Book': ['/title/tt0110213/?ref_=bo_ge_table_69', '469', 'The Jungle Book', '$43,229,904', '2,012', '$5,129,959', '1,880', 'Dec 25, 1994', 'Walt Disney Studios Motion Pictures\n\n'], 'Deadpool': ['/title/tt1431045/?ref_=bo_ge_table_24', '24', 'Deadpool', '$363,070,709', '3,856', '$132,434,639', '3,558', 'Feb 12, 2016', 'Twentieth Century Fox\n\n'], 'Jurassic Park': ['/title/tt0107290/?ref_=bo_ge_table_25', '25', 'Jurassic Park', '$357,067,947', '2,566', '$47,026,828', '2,404 ...

# %% [markdown]
# # `movies_dict`
# Get link stub from index page.

# %%
# scrape data from each row, including the link stub 

# rows = [row for row in table.find_all('tr')]  # tr tag is for rows

# movies_dict = {}

# for row in rows[1:2]:
#     items = row.find_all('td')
#     link = items[1].find('a')
#     title, url = link.text, link['href']
#     movies_dict[title] = [url] + [i.text for i in items]
# movies_dict
# Out:
# {'Avengers: Endgame': ['/title/tt4154796/?ref_=bo_ge_table_1',
#   '1',
#   'Avengers: Endgame',
#   '$858,373,000',
#   '4,662',
#   '$357,115,007',
#   '4,662',
#   'Apr 26, 2019',
#   'Walt Disney Studios Motion Pictures\n\n']}

# %% [markdown]
# # `adaptation_movies_df`

# %%
# df using movies dict from above, including link_stub

adaptation_movies_df = pd.DataFrame(movies_dict).T  #transpose
adaptation_movies_df.columns = ['link_stub', 'rank', 'movie_title', 
                    'lifetime_gross', 'max_theaters', 'opening_weekend', 
                    'opening_theathers', 'release_date', 'distributor']
adaptation_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 945 entries, The Avengers to Amityville: The Awakening
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   link_stub          945 non-null    object
#  1   rank               945 non-null    object
#  2   movie_title        945 non-null    object
#  3   lifetime_gross     945 non-null    object
#  4   max_theaters       945 non-null    object
#  5   opening_weekend    945 non-null    object
#  6   opening_theathers  945 non-null    object
#  7   release_date       945 non-null    object
#  8   distributor        945 non-null    object
# dtypes: object(9)
# memory usage: 73.8+ KB

# %% [markdown]
# # helper functions
# # `money_to_int()`  `runtime_to_minutes()`  `to_date()`

# %%
# helper functions parse strings into appropriate data types

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# # `get_movie_value()`

# %%
# function to scrape values from each movie page, will pass field_name in next function

def get_movie_value(soup, field_name):
 
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %% [markdown]
# # `get_movie_dict()`

# %%
# create movie dict to collect values from get_movie_value function from above

def get_movie_dict(link):
    
    base_url = 'https://www.boxofficemojo.com'
    
    # create full url to scrape
    url = base_url + link
    
    # request HTML and parse
    response = requests.get(url)
    status = response.status_code
    if status == 200:
        page = response.text
        soup = bs(page, "lxml")
    else:
        print(f"Oops! Received status code {status}")
        
    headers = ['movie_title', 
               'domestic_total_gross',
               'international_total_gross',
               'worldwide_total_gross',
               'domestic_opening',
               'budget',
               'release_date',
               'runtime',
               'distributor',
               'genres',
               'rating'
              ]

    #get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()
    print(title) # make sure scraper is working

    '''
    Get GROSS VALUES from performance summary table on left side of each movie page
    '''
    # domestic $$$
    try:     
        raw_domestic_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                        .find_all('span', class_='money')[0].text)
        # convert raw to int       
        domestic_total_gross = money_to_int(raw_domestic_total_gross)
    except:
        domestic_total_gross= 0
    
    # international $$$
    try: 
        raw_international_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                        .find_all('span', class_='money')[1].text)
        #convert raw to int    
        international_total_gross = money_to_int(raw_international_total_gross)
    except:
         international_total_gross = 0

    # worldwide $$$
    try: 
        raw_worldwide_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                        .find_all('span', class_='money')[2]
                                        .text)
        # convert raw to int
        worldwide_total_gross = money_to_int(raw_worldwide_total_gross)

    except:
        worldwide_total_gross = 0

    '''
    Get MOVIE DETAILS from summary details table in center of each movie page
    '''    
    # domestic opening $$$ 
    try: 
        raw_domestic_opening = get_movie_value(soup,'Domestic Opening')
        
        # convert to int
        domestic_opening = money_to_int(raw_domestic_opening)
    except:
        domestic_opening = 0
    
    # budget $$$
    try: 
        raw_budget = get_movie_value(soup,'Budget')
        
        # convert budget to int
        budget = money_to_int(raw_budget)
    except:
        budget = 0
    
    # release date
    try: 
        raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
        # convert date to dt
        release_date = to_date(raw_release_date)
    except:
        release_date = 0

    # runtime 
    try: 
        raw_runtime = get_movie_value(soup,'Running')
        # convert runtime to minutes
        runtime = runtime_to_minutes(raw_runtime)
    except:
        runtime = 0 
    
    # distributor
    try:  
        raw_distributor = get_movie_value(soup,'Distributor')
        # clean up 
        distributor = raw_distributor.replace('See full company information', '').replace('\n\n', '')
    except:
        distributor = 'NA' 

    # genres
    try: 
        genres = get_movie_value(soup,'Genres').replace('\n    \n        ', ', ')
    except:
        genres = 'NA'

    # rating    
    try: 
        rating = get_movie_value(soup,'MPAA')
    except:
        rating = 'NA'
    
    # movie dictionary
    movie_dict = dict(zip(headers, [title,
                                    domestic_total_gross,
                                    international_total_gross,
                                    worldwide_total_gross,
                                    domestic_opening,
                                    budget,
                                    release_date,
                                    runtime,
                                    distributor,
                                    genres,
                                    rating]))
    
#     print(movie_dict)

    return movie_dict

# %% [markdown]
# # `adaptation_movie_page_info_list`

# %%
# loop to pass link using get_movie_dict() function from above

adaptation_movie_page_info_list = []

for link in adaptation_movies_df.link_stub:
    adaptation_movie_page_info_list.append(get_movie_dict(link))
# Out:
# Avengers: Endgame
# Spider
# Black Panther
# Avengers: Infinity War
# The Avengers
# The Lion King
# The Dark Knight
# Beauty and the Beast
# Avengers: Age of Ultron
# The Dark Knight Rises
# Captain Marvel
# The Hunger Games: Catching Fire
# Wonder Woman
# Iron Man 3
# Captain America: Civil War
# The Hunger Games
# Spider
# Transformers: Revenge of the Fallen
# Spider

# %%
adaptation_movie_page_info_list
# Out:
# [{'movie_title': 'Avengers: Endgame',
#   'domestic_total_gross': 858373000,
#   'international_total_gross': 1939128328,
#   'worldwide_total_gross': 2797501328,
#   'domestic_opening': 357115007,
#   'budget': 356000000,
#   'release_date': datetime.datetime(2019, 4, 24, 0, 0),
#   'runtime': 181,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Drama, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 789170954,
#   'international_total_gross': 1080000000,
#   'worldwide_total_gross': 1869170954,
#   'domestic_opening': 260138569,
#   'budget': 0,
#   'release_date': datetime.datetime(2021, 12, 15, 0, 0),
#   'runtime': 148,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Black Panther',
#   'domestic_total_gross': 700426566,
#   'international_total_gross': 647171407,
#   'worldwide_total_gross': 1347597973,
#   'domestic_opening': 202003951,
#   'budget': 0,
#   'release_date': datetime.datetime(2018, 2, 13, 0, 0),
#   'runtime': 134,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Avengers: Infinity War',
#   'domestic_total_gross': 678815482,
#   'international_total_gross': 1369544272,
#   'worldwide_total_gross': 2048359754,
#   'domestic_opening': 257698183,
#   'budget': 0,
#   'release_date': datetime.datetime(2018, 4, 25, 0, 0),
#   'runtime': 149,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Avengers',
#   'domestic_total_gross': 623357910,
#   'international_total_gross': 895457605,
#   'worldwide_total_gross': 1518815515,
#   'domestic_opening': 207438708,
#   'budget': 220000000,
#   'release_date': datetime.datetime(2012, 4, 25, 0, 0),
#   'runtime': 143,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Lion King',
#   'domestic_total_gross': 543638043,
#   'international_total_gross': 1119261396,
#   'worldwide_total_gross': 1662899439,
#   'domestic_opening': 191770759,
#   'budget': 260000000,
#   'release_date': datetime.datetime(2019, 7, 11, 0, 0),
#   'runtime': 118,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Adventure, Animation, Drama, Family, Musical',
#   'rating': 'PG'},
#  {'movie_title': 'The Dark Knight',
#   'domestic_total_gross': 534987076,
#   'international_total_gross': 471115201,
#   'worldwide_total_gross': 1006102277,
#   'domestic_opening': 158411483,
#   'budget': 185000000,
#   'release_date': datetime.datetime(2008, 7, 16, 0, 0),
#   'runtime': 152,
#   'distributor': 'Warner Bros.',
#   'genres': 'Action, Crime, Drama, Thriller',
#   'rating': 'PG-13'},
#  {'movie_title': 'Beauty and the Beast',
#   'domestic_total_gross': 504481165,
#   'international_total_gross': 769095055,
#   'worldwide_total_gross': 1273576220,
#   'domestic_opening': 174750616,
#   'budget': 160000000,
#   'release_date': datetime.datetime(2017, 3, 16, 0, 0),
#   'runtime': 129,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Adventure, Family, Fantasy, Musical, Romance',
#   'rating': 'PG'},
#  {'movie_title': 'Avengers: Age of Ultron',
#   'domestic_total_gross': 459005868,
#   'international_total_gross': 943803672,
#   'worldwide_total_gross': 1402809540,
#   'domestic_opening': 191271109,
#   'budget': 250000000,
#   'release_date': datetime.datetime(2015, 4, 22, 0, 0),
#   'runtime': 141,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Dark Knight Rises',
#   'domestic_total_gross': 448149584,
#   'international_total_gross': 633003513,
#   'worldwide_total_gross': 1081153097,
#   'domestic_opening': 160887295,
#   'budget': 250000000,
#   'release_date': datetime.datetime(2012, 7, 19, 0, 0),
#   'runtime': 164,
#   'distributor': 'Warner Bros.',
#   'genres': 'Action, Crime, Drama',
#   'rating': 'PG-13'},
#  {'movie_title': 'Captain Marvel',
#   'domestic_total_gross': 426829839,
#   'international_total_gross': 701633133,
#   'worldwide_total_gross': 1128462972,
#   'domestic_opening': 153433423,
#   'budget': 160000000,
#   'release_date': datetime.datetime(2019, 3, 6, 0, 0),
#   'runtime': 123,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Hunger Games: Catching Fire',
#   'domestic_total_gross': 424668047,
#   'international_total_gross': 440343699,
#   'worldwide_total_gross': 865011746,
#   'domestic_opening': 158074286,
#   'budget': 130000000,
#   'release_date': datetime.datetime(2013, 11, 15, 0, 0),
#   'runtime': 146,
#   'distributor': 'Lionsgate',
#   'genres': 'Action, Adventure, Drama, Sci-Fi, Thriller',
#   'rating': 'PG-13'},
#  {'movie_title': 'Wonder Woman',
#   'domestic_total_gross': 412845172,
#   'international_total_gross': 410009114,
#   'worldwide_total_gross': 822854286,
#   'domestic_opening': 103251471,
#   'budget': 149000000,
#   'release_date': datetime.datetime(2017, 5, 30, 0, 0),
#   'runtime': 141,
#   'distributor': 'Warner Bros.',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi, War',
#   'rating': 'PG-13'},
#  {'movie_title': 'Iron Man 3',
#   'domestic_total_gross': 409013994,
#   'international_total_gross': 805797258,
#   'worldwide_total_gross': 1214811252,
#   'domestic_opening': 174144585,
#   'budget': 200000000,
#   'release_date': datetime.datetime(2013, 4, 24, 0, 0),
#   'runtime': 130,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Captain America: Civil War',
#   'domestic_total_gross': 408084349,
#   'international_total_gross': 745253147,
#   'worldwide_total_gross': 1153337496,
#   'domestic_opening': 179139142,
#   'budget': 250000000,
#   'release_date': datetime.datetime(2016, 4, 27, 0, 0),
#   'runtime': 147,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Hunger Games',
#   'domestic_total_gross': 408010692,
#   'international_total_gross': 286384032,
#   'worldwide_total_gross': 694394724,
#   'domestic_opening': 152535747,
#   'budget': 78000000,
#   'release_date': datetime.datetime(2012, 3, 8, 0, 0),
#   'runtime': 142,
#   'distributor': 'Lionsgate',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'rating': 'PG-13'},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 407022860,
#   'international_total_gross': 418002176,
#   'worldwide_total_gross': 825025036,
#   'domestic_opening': 114844116,
#   'budget': 139000000,
#   'release_date': datetime.datetime(2002, 5, 3, 0, 0),
#   'runtime': 121,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Transformers: Revenge of the Fallen',
#   'domestic_total_gross': 402111870,
#   'international_total_gross': 434191823,
#   'worldwide_total_gross': 836303693,
#   'domestic_opening': 108966307,
#   'budget': 200000000,
#   'release_date': datetime.datetime(2009, 6, 19, 0, 0),
#   'runtime': 149,
#   'distributor': 'DreamWorks',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 390532085,
#   'international_total_gross': 741395911,
#   'worldwide_total_gross': 1131927996,
#   'domestic_opening': 92579212,
#   'budget': 160000000,
#   'release_date': datetime.datetime(2019, 6, 28, 0, 0),
#   'runtime': 129,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'}]

# %% [markdown]
# # `adaptation_movie_info_df` from `adaptation_movie_page_info_list`

# %%
# #convert list of dict to df

adaptation_movie_info_df = pd.DataFrame(adaptation_movie_page_info_list)  
adaptation_movie_info_df.set_index('movie_title', inplace=True)

adaptation_movie_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, Avengers: Endgame to Spider
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   domestic_total_gross       19 non-null     int64
#  1   international_total_gross  19 non-null     int64
#  2   worldwide_total_gross      19 non-null     int64
#  3   domestic_opening           19 non-null     int64
#  4   budget                     19 non-null     int64
#  5   release_date               19 non-null     datetime64[ns]
#  6   runtime                    19 non-null     int64
#  7   distributor                19 non-null     object
#  8   genres                     19 non-null     object
#  9   rating                     19 non-null     object
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 1.6+ KB

# %%
adaptation_movie_page_info_list
# Out:
# [{'movie_title': 'Avengers: Endgame',
#   'domestic_total_gross': 858373000,
#   'international_total_gross': 1939128328,
#   'worldwide_total_gross': 2797501328,
#   'domestic_opening': 357115007,
#   'budget': 356000000,
#   'release_date': datetime.datetime(2019, 4, 24, 0, 0),
#   'runtime': 181,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Drama, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 789170954,
#   'international_total_gross': 1080000000,
#   'worldwide_total_gross': 1869170954,
#   'domestic_opening': 260138569,
#   'budget': 0,
#   'release_date': datetime.datetime(2021, 12, 15, 0, 0),
#   'runtime': 148,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Black Panther',
#   'domestic_total_gross': 700426566,
#   'international_total_gross': 647171407,
#   'worldwide_total_gross': 1347597973,
#   'domestic_opening': 202003951,
#   'budget': 0,
#   'release_date': datetime.datetime(2018, 2, 13, 0, 0),
#   'runtime': 134,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Avengers: Infinity War',
#   'domestic_total_gross': 678815482,
#   'international_total_gross': 1369544272,
#   'worldwide_total_gross': 2048359754,
#   'domestic_opening': 257698183,
#   'budget': 0,
#   'release_date': datetime.datetime(2018, 4, 25, 0, 0),
#   'runtime': 149,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Avengers',
#   'domestic_total_gross': 623357910,
#   'international_total_gross': 895457605,
#   'worldwide_total_gross': 1518815515,
#   'domestic_opening': 207438708,
#   'budget': 220000000,
#   'release_date': datetime.datetime(2012, 4, 25, 0, 0),
#   'runtime': 143,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Lion King',
#   'domestic_total_gross': 543638043,
#   'international_total_gross': 1119261396,
#   'worldwide_total_gross': 1662899439,
#   'domestic_opening': 191770759,
#   'budget': 260000000,
#   'release_date': datetime.datetime(2019, 7, 11, 0, 0),
#   'runtime': 118,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Adventure, Animation, Drama, Family, Musical',
#   'rating': 'PG'},
#  {'movie_title': 'The Dark Knight',
#   'domestic_total_gross': 534987076,
#   'international_total_gross': 471115201,
#   'worldwide_total_gross': 1006102277,
#   'domestic_opening': 158411483,
#   'budget': 185000000,
#   'release_date': datetime.datetime(2008, 7, 16, 0, 0),
#   'runtime': 152,
#   'distributor': 'Warner Bros.',
#   'genres': 'Action, Crime, Drama, Thriller',
#   'rating': 'PG-13'},
#  {'movie_title': 'Beauty and the Beast',
#   'domestic_total_gross': 504481165,
#   'international_total_gross': 769095055,
#   'worldwide_total_gross': 1273576220,
#   'domestic_opening': 174750616,
#   'budget': 160000000,
#   'release_date': datetime.datetime(2017, 3, 16, 0, 0),
#   'runtime': 129,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Adventure, Family, Fantasy, Musical, Romance',
#   'rating': 'PG'},
#  {'movie_title': 'Avengers: Age of Ultron',
#   'domestic_total_gross': 459005868,
#   'international_total_gross': 943803672,
#   'worldwide_total_gross': 1402809540,
#   'domestic_opening': 191271109,
#   'budget': 250000000,
#   'release_date': datetime.datetime(2015, 4, 22, 0, 0),
#   'runtime': 141,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Dark Knight Rises',
#   'domestic_total_gross': 448149584,
#   'international_total_gross': 633003513,
#   'worldwide_total_gross': 1081153097,
#   'domestic_opening': 160887295,
#   'budget': 250000000,
#   'release_date': datetime.datetime(2012, 7, 19, 0, 0),
#   'runtime': 164,
#   'distributor': 'Warner Bros.',
#   'genres': 'Action, Crime, Drama',
#   'rating': 'PG-13'},
#  {'movie_title': 'Captain Marvel',
#   'domestic_total_gross': 426829839,
#   'international_total_gross': 701633133,
#   'worldwide_total_gross': 1128462972,
#   'domestic_opening': 153433423,
#   'budget': 160000000,
#   'release_date': datetime.datetime(2019, 3, 6, 0, 0),
#   'runtime': 123,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Hunger Games: Catching Fire',
#   'domestic_total_gross': 424668047,
#   'international_total_gross': 440343699,
#   'worldwide_total_gross': 865011746,
#   'domestic_opening': 158074286,
#   'budget': 130000000,
#   'release_date': datetime.datetime(2013, 11, 15, 0, 0),
#   'runtime': 146,
#   'distributor': 'Lionsgate',
#   'genres': 'Action, Adventure, Drama, Sci-Fi, Thriller',
#   'rating': 'PG-13'},
#  {'movie_title': 'Wonder Woman',
#   'domestic_total_gross': 412845172,
#   'international_total_gross': 410009114,
#   'worldwide_total_gross': 822854286,
#   'domestic_opening': 103251471,
#   'budget': 149000000,
#   'release_date': datetime.datetime(2017, 5, 30, 0, 0),
#   'runtime': 141,
#   'distributor': 'Warner Bros.',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi, War',
#   'rating': 'PG-13'},
#  {'movie_title': 'Iron Man 3',
#   'domestic_total_gross': 409013994,
#   'international_total_gross': 805797258,
#   'worldwide_total_gross': 1214811252,
#   'domestic_opening': 174144585,
#   'budget': 200000000,
#   'release_date': datetime.datetime(2013, 4, 24, 0, 0),
#   'runtime': 130,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Captain America: Civil War',
#   'domestic_total_gross': 408084349,
#   'international_total_gross': 745253147,
#   'worldwide_total_gross': 1153337496,
#   'domestic_opening': 179139142,
#   'budget': 250000000,
#   'release_date': datetime.datetime(2016, 4, 27, 0, 0),
#   'runtime': 147,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'The Hunger Games',
#   'domestic_total_gross': 408010692,
#   'international_total_gross': 286384032,
#   'worldwide_total_gross': 694394724,
#   'domestic_opening': 152535747,
#   'budget': 78000000,
#   'release_date': datetime.datetime(2012, 3, 8, 0, 0),
#   'runtime': 142,
#   'distributor': 'Lionsgate',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'rating': 'PG-13'},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 407022860,
#   'international_total_gross': 418002176,
#   'worldwide_total_gross': 825025036,
#   'domestic_opening': 114844116,
#   'budget': 139000000,
#   'release_date': datetime.datetime(2002, 5, 3, 0, 0),
#   'runtime': 121,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Transformers: Revenge of the Fallen',
#   'domestic_total_gross': 402111870,
#   'international_total_gross': 434191823,
#   'worldwide_total_gross': 836303693,
#   'domestic_opening': 108966307,
#   'budget': 200000000,
#   'release_date': datetime.datetime(2009, 6, 19, 0, 0),
#   'runtime': 149,
#   'distributor': 'DreamWorks',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 390532085,
#   'international_total_gross': 741395911,
#   'worldwide_total_gross': 1131927996,
#   'domestic_opening': 92579212,
#   'budget': 160000000,
#   'release_date': datetime.datetime(2019, 6, 28, 0, 0),
#   'runtime': 129,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'rating': 'PG-13'}]

# %% [markdown]
# # 4. Merge `adaptation_movies_df` and `adaptation_movie_info_df` dfs
# # `g_movies` df

# %%
# match this back up with the movie information collected from the table by merging  dataframes
adaptation_movies_df = adaptation_movies_df.merge(adaptation_movie_info_df, left_index=True, right_index=True)
adaptation_movies_df
# Out:
#                                                                  link_stub  \
# Avengers: Age of Ultron               /title/tt2395427/?ref_=bo_ge_table_9
# Avengers: Endgame                     /title/tt4154796/?ref_=bo_ge_table_1
# Avengers: Infinity War                /title/tt4154756/?ref_=bo_ge_table_4
# Beauty and the Beast                  /title/tt2771200/?ref_=bo_ge_table_8
# Black Panther                         /title/tt1825683/?ref_=bo_ge_table_3
# Captain America: Civil War           /title/tt3498820/?ref_=bo_ge_table_15
# Captain Marvel                       /title/tt4154664/?ref_=bo_ge_table_11
# Iron Man 3                           /title/tt1300854/?ref_=bo_ge_table_14
# The Avengers                          /title/tt0848228/?ref_=bo_ge_table_5
# The Dark Knight                       /title/tt0468569/?ref_=bo_ge_table_7
# The Dark Knight Rises                /title/tt1345836/?ref_=bo_ge_table_10
# The Hunger Games                     /title/tt1392170/?ref_=bo_ge_table_16
# The Hunger Games: Catching Fire      /title/tt1951264/?ref_=bo_ge_table_12
# The Lion King                         /title/tt6105098/?ref_=bo_ge_table_6
# Transformers: Revenge of the Fallen  /title/tt1055369/?ref_=bo_ge_table_18
# Wonder Woman                         /title/tt0451279/?ref_=bo_ge_table_13
#
#                                     rank                          movie_title  \
# Avengers: Age of Ultron                9              Avengers: Age of Ultron
# Avengers: Endgame                      1                    Avengers: Endgame
# Avengers: Infinity War                 4               Avengers: Infinity War
# Beauty and the Beast                   8                 Beauty and the Beast
# Black Panther                          3                        Black Panther
# Captain America: Civil War            15           Captain America: Civil War
# Captain Marvel                        11                       Captain Marvel
# Iron Man 3                            14                           Iron Man 3
# The Avengers                           5                         The Avengers
# The Dark Knight                        7                      The Dark Knight
# The Dark Knight Rises                 10                The Dark Knight Rises
# The Hunger Games                      16                     The Hunger Games
# The Hunger Games: Catching Fire       12      The Hunger Games: Catching Fire
# The Lion King                          6                        The Lion King
# Transformers: Revenge of the Fallen   18  Transformers: Revenge of the Fallen
# Wonder Woman                          13                         Wonder Woman
#
#                                     lifetime_gross max_theaters  \
# Avengers: Age of Ultron               $459,005,868        4,276
# Avengers: Endgame                     $858,373,000        4,662
# Avengers: Infinity War                $678,815,482        4,474
# Beauty and the Beast                  $504,014,165        4,210
# Black Panther                         $700,059,566        4,084
# Captain America: Civil War            $408,084,349        4,226
# Captain Marvel                        $426,829,839        4,310
# Iron Man 3                            $409,013,994        4,253
# The Avengers                          $623,357,910        4,349
# The Dark Knight                       $533,345,358        4,366
# The Hunger Games: Catching Fire                                Lionsgate
# The Lion King                        Walt Disney Studios Motion Pictures
# Transformers: Revenge of the Fallen                           DreamWorks
# Wonder Woman                                                Warner Bros.
#
#                                                                            genres  \
# Avengers: Age of Ultron                                 Action, Adventure, Sci-Fi
# Avengers: Endgame                                Action, Adventure, Drama, Sci-Fi
# Avengers: Infinity War                                  Action, Adventure, Sci-Fi
# Beauty and the Beast                 Adventure, Family, Fantasy, Musical, Romance
# Black Panther                                           Action, Adventure, Sci-Fi
# Captain America: Civil War                              Action, Adventure, Sci-Fi
# Captain Marvel                                          Action, Adventure, Sci-Fi
# Iron Man 3                                              Action, Adventure, Sci-Fi
# The Avengers                                            Action, Adventure, Sci-Fi
# The Dark Knight                                    Action, Crime, Drama, Thriller
# The Dark Knight Rises                                        Action, Crime, Drama
# The Hunger Games                              Action, Adventure, Sci-Fi, Thriller
# The Hunger Games: Catching Fire        Action, Adventure, Drama, Sci-Fi, Thriller
# The Lion King                        Adventure, Animation, Drama, Family, Musical
# Transformers: Revenge of the Fallen                     Action, Adventure, Sci-Fi
# Wonder Woman                              Action, Adventure, Fantasy, Sci-Fi, War
#
#                                     rating
# Avengers: Age of Ultron              PG-13
# Avengers: Endgame                    PG-13
# Avengers: Infinity War               PG-13
# Beauty and the Beast                    PG
# Black Panther                        PG-13
# Captain America: Civil War           PG-13
# Captain Marvel                       PG-13
# Iron Man 3                           PG-13
# The Avengers                         PG-13
# The Dark Knight                      PG-13
# The Dark Knight Rises                PG-13
# The Hunger Games                     PG-13
# The Hunger Games: Catching Fire      PG-13
# The Lion King                           PG
# Transformers: Revenge of the Fallen  PG-13
# Wonder Woman                         PG-13

# %%
adaptation_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, Avengers: Age of Ultron to Wonder Woman
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   link_stub                  16 non-null     object
#  1   rank                       16 non-null     object
#  2   movie_title                16 non-null     object
#  3   lifetime_gross             16 non-null     object
#  4   max_theaters               16 non-null     object
#  5   opening_weekend            16 non-null     object
#  6   opening_theathers          16 non-null     object
#  7   release_date_x             16 non-null     object
#  8   distributor_x              16 non-null     object
#  9   domestic_total_gross       16 non-null     int64
#  10  international_total_gross  16 non-null     int64
#  11  worldwide_total_gross      16 non-null     int64
#  12  domestic_opening           16 non-null     int64
#  13  budget                     16 non-null     int64
#  14  release_date_y             16 non-null     datetime64[ns]
#  15  runtime                    16 non-null     int64
#  16  distributor_y              16 non-null     object
#  17  genres                     16 non-null     object
#  18  rating                     16 non-null     object
# dtypes: datetime64[ns](1), int64(6), object(12)
# memory usage: 2.5+ KB

# %%
# picke df 
adaptation_movies_df1 = adaptation_movies_df
adaptation_movies_df1.to_pickle('adaptation_movies_df1.pkl')

# %%
# save to csv
adaptation_movies_df1.to_csv(r'/Users/sandraparedes/Dropbox/Mac/Downloads/adaptation_movies_df1.csv', index=False)

# %%
# pd.read_csv('g_movies_p1_df.csv')

# %%
# # read pickle file as dataframe
# g_movies_df = pd.read_pickle('g_movies_df.pkl')
# g_movies_df
